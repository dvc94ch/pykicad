# %%
# %load_ext autoreload
# %autoreload 2


import pykicad
A = pykicad.Pcb().from_file('/Users/zfphil/Desktop/test.kicad_pcb')
# Out:
# C
# C
# A
# AA
# C
# A
# AA
# C
# C
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# C
# C
# A
# AA
# C
# A
# AA
# C
# C
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# C
# C
# B
# C
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# A
# AA
# C
# B
# C
# A
# AA
# C
# A
# AA
# A
# AA
# A
# AA
# C
# C
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# C
# A
# AA
# C
# B
# C
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# A
# AA
# C
# C
# A
# AA
# A
# AA
# A
# AA
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# AA
# C
# C
# A
# ...
